# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams["font.size"] = 14
plt.rcParams["figure.dpi"] = 300

m_red = 
# %load_ext autoreload
# Out:
#   File "<ipython-input-1-cf4c68713c79>", line 7
#     m_red =
#             ^
# SyntaxError: invalid syntax

# %%
r = []
theta = []
v = []
with open('mgnh.txt', 'r') as f:
    lines = f.readlines()
    for l in lines:
        r.append(float(l[:13]))
        theta.append(float(l[13:20]))
        v.append(float(l[20:]))

r = np.array(r)
theta = np.array(theta)
v = np.array(v)

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# surf = ax.plot_trisurf(r, theta, v, cmap=plt.get_cmap('jet'))
surf = ax.plot_trisurf(theta[v < 100], r[v < 100], v[v < 100], cmap=plt.get_cmap('jet'))
fig.colorbar(surf, shrink=0.5, aspect=5)    
# ax.set_zlim(-100, 3000)

# ax.set_zlim(-100, 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2ec53203a2c9> in <module>
# ----> 1 fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#       2 # surf = ax.plot_trisurf(r, theta, v, cmap=plt.get_cmap('jet'))
#       3 surf = ax.plot_trisurf(theta[v < 100], r[v < 100], v[v < 100], cmap=plt.get_cmap('jet'))
#       4 fig.colorbar(surf, shrink=0.5, aspect=5)
#       5 # ax.set_zlim(-100, 3000)
#
# NameError: name 'plt' is not defined

# %%
plt.tricontour(theta[v < 100], r[v < 100], v[v < 100], levels=50)

# %%
# %autoreload

from dvr import dvr_2d

dvr_2d(r, theta, v, )
