# %%
import matplotlib.pyplot as plt
from lib.greedy_circs import build_circuit_ent

from qiskit import Aer
from qiskit.circuit import Parameter
from qiskit.algorithms import VQE
from qiskit.algorithms.optimizers import COBYLA, L_BFGS_B, SLSQP, BOBYQA, NELDER_MEAD, SNOBFIT
from qiskit.circuit.library import TwoLocal
from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit.quantum_info.operators import Operator
from qiskit.opflow import PrimitiveOp
# %matplotlib inline

plt.rcParams["figure.figsize"] = (4,4)
plt.rcParams["font.size"] = 14
plt.rcParams["figure.dpi"] = 300

# %load_ext autoreload

# %%
my_gate_names = {
    'name': 'iqx',
    # 'subfontsize': -1,
    # "displaytext": {
    #     'ry': ' '
    # },
    "displaycolor": {
        "ry": [
            "#9F1853",
            "#9F1853"
        ],
        "cx": [ # gate name
            "#002D9C",
            "#000000"
        ],
    },
}

# %%
# %autoreload
ansatz_options = {
    'type': 'greedyent',
    'constructive': False,
    'num_qubits': 3,
    'add_rs': True,
    'reps': 1
}
removed_gates = [1]
ansatz = build_circuit_ent(ansatz_options, removed_gates)
ansatz.draw(output='mpl', plot_barriers=False, initial_state=True)

# %%
ansatz1 = TwoLocal(3, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=1).decompose()
print(ansatz1.parameters)
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# ParameterView([ParameterVectorElement(θ[0]), ParameterVectorElement(θ[1]), ParameterVectorElement(θ[2]), ParameterVectorElement(θ[3]), ParameterVectorElement(θ[4]), ParameterVectorElement(θ[5])])
# 5

# %%
ansatz1 = TwoLocal(3, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=2).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 9

# %%
ansatz1 = TwoLocal(3, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=3).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 13

# %%
ansatz1 = TwoLocal(3, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=1).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 4

# %%
ansatz1 = TwoLocal(3, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=2).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 7

# %%
ansatz1 = TwoLocal(3, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=3).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 10

# %%
ansatz1 = TwoLocal(4, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=1).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 7

# %%
ansatz1 = TwoLocal(4, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=2).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 12

# %%
ansatz1 = TwoLocal(4, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=3).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 17

# %%
ansatz1 = TwoLocal(4, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=1).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 5

# %%
ansatz1 = TwoLocal(4, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=2).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 8

# %%
ansatz1 = TwoLocal(4, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=3).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 11

# %%
for i in range(1, 4):
    ansatz = TwoLocal(4, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=i).decompose()
    print(ansatz.depth())
# Out:
# 5
# 8
# 11

# %%
for i in range(1, 4):
    ansatz = TwoLocal(4, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=i).decompose()
    print(ansatz.depth())
# Out:
# 7
# 12
# 17

# %%
for i in range(1, 5):
    ansatz = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=i).decompose()
    print(ansatz.depth())
# Out:
# 9
# 15
# 21
# 27

# %%
for i in range(1, 5):
    ansatz = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=i).decompose()
    print(ansatz.depth())
# Out:
# 6
# 9
# 12
# 15

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=1).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 9

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=2).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 15

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=3).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 21

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=4).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 27

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='full', reps=5).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 33

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=1).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1, style=my_gate_names)
# Out:
# 6

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=2).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 9

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=3).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 12

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=4).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 15

# %%
ansatz1 = TwoLocal(5, rotation_blocks=['ry'], entanglement_blocks='cx', entanglement='linear', reps=5).decompose()
print(ansatz1.depth())
ansatz1.draw(output='mpl', fold=-1)
# Out:
# 18
