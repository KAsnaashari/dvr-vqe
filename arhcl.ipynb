# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams["font.size"] = 14
plt.rcParams["figure.dpi"] = 300

# %load_ext autoreload

# %%
r = []
theta = []
v = []
with open('arhcl.txt', 'r') as f:
    lines = f.readlines()
    for l in lines:
        r.append(float(l[:22]))
        theta.append(float(l[22:53]))
        v.append(float(l[53:-1]))

r = np.array(r)
theta = np.arccos(np.array(theta))
v = np.array(v)
# print(theta)

# %%
r = r[::2]
costheta = theta[::2]
theta = theta[::2]
v = v[::2]

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# surf = ax.plot_trisurf(r, theta, v, cmap=plt.get_cmap('jet'))
surf = ax.plot_trisurf(theta[r < 6], r[r < 6], v[r < 6])
# surf = ax.plot_trisurf(theta[v < 100], r[v < 100], v[v < 100], cmap=plt.get_cmap('jet'))
# fig.colorbar(surf, shrink=0.5, aspect=5)    
# ax.set_zlim(-100, 3000)

# ax.set_zlim(-100, 100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b21cc6637706> in <module>
#       1 fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#       2 # surf = ax.plot_trisurf(r, theta, v, cmap=plt.get_cmap('jet'))
# ----> 3 surf = ax.plot_surf(theta[r < 6], r[r < 6], v[r < 6])
#       4 # surf = ax.plot_trisurf(theta[v < 100], r[v < 100], v[v < 100], cmap=plt.get_cmap('jet'))
#       5 # fig.colorbar(surf, shrink=0.5, aspect=5)
#
# AttributeError: 'Axes3DSubplot' object has no attribute 'plot_surf'

# %%
theta_p, r_p, v_p = theta[v < 0], r[v < 0], v[v < 0]
plt.tricontour(theta_p[r_p < 5.5], r_p[r_p < 5.5], v_p[r_p < 5.5], levels=50)
plt.ylim(3, 5.5)
# Out:
# (3.0, 5.5)

# %%
# %autoreload

from dvr import dvr_2d

dvr_2d(r, theta, v, )
